# %% [markdown]
# ### Data Cleaning Project

# %%
import seaborn as sns
import pandas as pd
import numpy as np

print(sns.__version__)
print(pd.__version__)
print(np.__version__)
# Out:
# 0.13.2
# 2.2.3
# 2.2.6

# %%
''' 
planets data load from seaborn builting dataset
'''
sns.get_dataset_names()
Planets_dataset=sns.load_dataset(
    'planets'
)

Planets_dataset.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
''' Dataset Information check  '''

Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  992 non-null    float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
mask=Planets_dataset['orbital_period'].isnull()
Planets_dataset[mask]
# Out:
#                          method  number  orbital_period  mass  distance  year
# 29                      Imaging       1             NaN   NaN     45.52  2005
# 30                      Imaging       1             NaN   NaN    165.00  2007
# 31                      Imaging       1             NaN   NaN    140.00  2004
# 33                      Imaging       1             NaN   NaN       NaN  2008
# 34                      Imaging       1             NaN   NaN    145.00  2013
# 35                      Imaging       1             NaN   NaN    139.00  2004
# 36                      Imaging       1             NaN   NaN     18.39  2006
# 54                      Imaging       1             NaN   NaN     52.03  2012
# 69                      Imaging       1             NaN   NaN    145.00  2008
# 70                      Imaging       1             NaN   NaN     36.00  2013
# 71                      Imaging       1             NaN   NaN    140.00  2010
# ...

# %%
average_orbital_period=Planets_dataset['orbital_period'].mean()
average_orbital_period
# Out:
# np.float64(2002.9175960947582)

# %%
Planets_dataset['orbital_period'] = Planets_dataset['orbital_period'].fillna(
    value=average_orbital_period
)

# %%
Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  1035 non-null   float64
#  3   mass            513 non-null    float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
Planets_dataset.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
average_mass=Planets_dataset['mass'].mean()
average_mass
# Out:
# np.float64(2.6381605847953216)

# %%
Planets_dataset['mass'] = Planets_dataset['mass'].fillna(
    value=average_mass
)

# %%
Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  1035 non-null   float64
#  3   mass            1035 non-null   float64
#  4   distance        808 non-null    float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %%
average_distance  = Planets_dataset['distance'].mean()
average_distance
# Out:
# np.float64(264.06928217821786)

# %%
Planets_dataset['distance'] = Planets_dataset['distance'].fillna(
    value=average_distance
)

# %%
Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1035 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1035 non-null   object
#  1   number          1035 non-null   int64
#  2   orbital_period  1035 non-null   float64
#  3   mass            1035 non-null   float64
#  4   distance        1035 non-null   float64
#  5   year            1035 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 48.6+ KB

# %% [markdown]
# ### Clean Duplicated

# %%
mask = Planets_dataset.duplicated()
mask.value_counts()
# Out:
# False    1031
# True        4
# Name: count, dtype: int64

# %%
Planets_dataset = Planets_dataset.drop_duplicates()

# %%
Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1031 entries, 0 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          1031 non-null   object
#  1   number          1031 non-null   int64
#  2   orbital_period  1031 non-null   float64
#  3   mass            1031 non-null   float64
#  4   distance        1031 non-null   float64
#  5   year            1031 non-null   int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 56.4+ KB

# %%
''' Outlyer Function '''

def iqr(item):
    Q1 = item.quantile(0.25)
    Q3 = item.quantile(0.75) 
    IQR = Q3 - Q1
    L = Q1 - 1.5 * IQR
    U = Q3 + 1.5  * IQR
    non_outlyer=item.between(L,U)
    global Planets_dataset
    Planets_dataset=Planets_dataset[non_outlyer]
    return Planets_dataset
    

iqr(Planets_dataset['distance'])
iqr(Planets_dataset['mass'])
iqr(Planets_dataset['orbital_period'])
# Out:
#                method  number  orbital_period      mass  distance  year
# 1     Radial Velocity       1      874.774000  2.210000     56.95  2008
# 2     Radial Velocity       1      763.000000  2.600000     19.84  2011
# 5     Radial Velocity       1      185.840000  4.800000     76.39  2008
# 7     Radial Velocity       1      798.500000  2.638161     21.41  1996
# 9     Radial Velocity       2      452.800000  1.990000     74.79  2010
# ...               ...     ...             ...       ...       ...   ...
# 1030          Transit       1        3.941507  2.638161    172.00  2006
# 1031          Transit       1        2.615864  2.638161    148.00  2007
# 1032          Transit       1        3.191524  2.638161    174.00  2007
# 1033          Transit       1        4.125083  2.638161    293.00  2008
# 1034          Transit       1        4.187757  2.638161    260.00  2008
#
# [740 rows x 6 columns]

# %%
Planets_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 1 to 1034
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   method          740 non-null    object
#  1   number          740 non-null    int64
#  2   orbital_period  740 non-null    float64
#  3   mass            740 non-null    float64
#  4   distance        740 non-null    float64
#  5   year            740 non-null    int64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 40.5+ KB

# %%
Planets_dataset.head()
# Out:
#             method  number  orbital_period      mass  distance  year
# 1  Radial Velocity       1         874.774  2.210000     56.95  2008
# 2  Radial Velocity       1         763.000  2.600000     19.84  2011
# 5  Radial Velocity       1         185.840  4.800000     76.39  2008
# 7  Radial Velocity       1         798.500  2.638161     21.41  1996
# 9  Radial Velocity       2         452.800  1.990000     74.79  2010

# %%
sns.set(
    style='whitegrid',
    palette='flare',
    font='Arial',
    font_scale=1
)

# %%
grap = sns.PairGrid(Planets_dataset)
grap.map_upper(sns.histplot,cbar=True)
grap.map_diag(sns.kdeplot,fill=True)
grap.map_lower(sns.histplot,kde=True)
